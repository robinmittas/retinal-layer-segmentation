# %% [markdown]
# # Notebook to run transfer learning on IRD patients using pretrained model

# %% [markdown]
# ## Library Imports

# %%
import os
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

from retinal_seg.config import BATCH_SIZE, EPOCHS, IMG_CHANNELS, IMG_HEIGHT, IMG_WIDTH, NUM_CLASSES
from retinal_seg.data.loader import datasets_from_maps, train_val_test_split
from retinal_seg.data.preprocessing import get_class_distribution
from retinal_seg.model.losses import dice_coef, weighted_ce_dice
from retinal_seg.model.unet import build_unet

# %%
FIG_DIR = Path(os.getcwd()).parent / "figures" / "ird_direct_training_weighted_CE"
FIG_DIR.mkdir(parents=True, exist_ok=True)

MODEL_DIR = (
    Path(os.getcwd()).parent
    / "trained_models_checkpoint"
    / "ird_direct_training_weighted_CE"
)
MODEL_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Get paths for train/ valid and test set

# %%
# Files are stored within this directory
directory = (
    Path(os.getcwd()).parent.parent
    / "data"
    / "Diseased_Anonymized"
)

x_path = []
y_path = []

x_y_map = {}

for file in sorted(os.listdir(directory)):
    filename = os.fsdecode(file)
    if filename.endswith(".npy") and "Final" not in filename:
        idx_x = filename.split(".npy")[0].split("_")[-1]
        x_y_map[str(directory) + "/" + filename] = (
            str(directory)
            + "/"
            + filename.split(".")[0]
            + f"_Surfaces_Retina-JEI-Final_{idx_x}.npy"
        )

# %%
len(x_y_map)
# Out:
# 1225

# %% [markdown]
# ## Get class distribution

# %%
class_0, class_1, class_2, class_3 = get_class_distribution(x_y_map)
print(f"Background: {class_0}, ILM - OPL: {class_1}, ONL: {class_2}, BMEIS - OP-RPE: {class_3}")

# %% [markdown]
# ## Split training set by patient names
# #### Patient name defined as first two words seperated by "_" within file name

# %%
train_x_y_map, val_x_y_map, test_x_y_map = train_val_test_split(x_y_map, val_ratio=0.1, test_ratio=0.1)

# %%
len(train_x_y_map)
# Out:
# 931

# %% [markdown]
# ## Define dataloader

# %%
train_dataset, val_dataset, test_dataset = datasets_from_maps(train_x_y_map, val_x_y_map, test_x_y_map, batch_size=BATCH_SIZE)

# %%
SHUFFLE_BUFFER_SIZE = 1

# %% [markdown]
# ## Define model and freeze all layers apart of BN layers

# %%
model_new = build_unet(
    pretrained_weights=None,
    img_width=IMG_WIDTH,
    img_height=IMG_HEIGHT,
    img_channels=IMG_CHANNELS,
    n_classes=NUM_CLASSES,
    last_activation="softmax",
    compile_model=True,
    bn_list=[True] * 14,
    drop_rate=0.0,
    non_local_attention=False,
    momentum=0.9,
    loss=weighted_ce_dice,
)

# %% [markdown]
# ## Train model

# %%
early_stopping = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    patience=5,
    restore_best_weights=True,
)

history = model_new.fit(
    train_dataset, validation_data=val_dataset, epochs=30, callbacks=[early_stopping]
)
# Out:
# Epoch 1/30
# tf.Tensor([[1.  1.  3.5 1. ]], shape=(1, 4), dtype=float32)
# tf.Tensor([[1.  1.  3.5 1. ]], shape=(1, 4), dtype=float32)
# 117/117 [==============================] - ETA: 0s - loss: 0.8247 - dice_coef: 0.7036tf.Tensor([[1.  1.  3.5 1. ]], shape=(1, 4), dtype=float32)
# 117/117 [==============================] - 60s 509ms/step - loss: 0.8247 - dice_coef: 0.7036 - val_loss: 0.3259 - val_dice_coef: 0.8908
# Epoch 2/30
# 117/117 [==============================] - 57s 483ms/step - loss: 0.3113 - dice_coef: 0.8767 - val_loss: 0.2897 - val_dice_coef: 0.9074
# Epoch 3/30
# 117/117 [==============================] - 57s 485ms/step - loss: 0.1995 - dice_coef: 0.9246 - val_loss: 0.2242 - val_dice_coef: 0.9296
# Epoch 4/30
# 117/117 [==============================] - 57s 485ms/step - loss: 0.1501 - dice_coef: 0.9453 - val_loss: 0.1436 - val_dice_coef: 0.9574
# Epoch 5/30
# 117/117 [==============================] - 57s 487ms/step - loss: 0.1193 - dice_coef: 0.9575 - val_loss: 0.1165 - val_dice_coef: 0.9661
# Epoch 6/30
# 117/117 [==============================] - 58s 496ms/step - loss: 0.1098 - dice_coef: 0.9634 - val_loss: 0.1036 - val_dice_coef: 0.9718
# Epoch 7/30
# 117/117 [==============================] - 57s 485ms/step - loss: 0.0943 - dice_coef: 0.9686 - val_loss: 0.1087 - val_dice_coef: 0.9729
# Epoch 8/30
# 117/117 [==============================] - 56s 480ms/step - loss: 0.0862 - dice_coef: 0.9718 - val_loss: 0.0910 - val_dice_coef: 0.9766
# Epoch 9/30
# 117/117 [==============================] - 56s 482ms/step - loss: 0.0807 - dice_coef: 0.9742 - val_loss: 0.0811 - val_dice_coef: 0.9786
# Epoch 10/30
# 117/117 [==============================] - 56s 483ms/step - loss: 0.0736 - dice_coef: 0.9768 - val_loss: 0.0773 - val_dice_coef: 0.9795
# Epoch 11/30
# 117/117 [==============================] - 57s 487ms/step - loss: 0.0687 - dice_coef: 0.9789 - val_loss: 0.0794 - val_dice_coef: 0.9767
# Epoch 12/30
# 117/117 [==============================] - 58s 494ms/step - loss: 0.0639 - dice_coef: 0.9804 - val_loss: 0.0799 - val_dice_coef: 0.9817
# Epoch 13/30
# 117/117 [==============================] - 59s 502ms/step - loss: 0.0574 - dice_coef: 0.9824 - val_loss: 0.0741 - val_dice_coef: 0.9829
# Epoch 14/30
# 117/117 [==============================] - 58s 499ms/step - loss: 0.0535 - dice_coef: 0.9837 - val_loss: 0.0778 - val_dice_coef: 0.9833
# Epoch 15/30
# 117/117 [==============================] - 59s 500ms/step - loss: 0.0536 - dice_coef: 0.9841 - val_loss: 0.0995 - val_dice_coef: 0.9775
# Epoch 16/30
# 117/117 [==============================] - 60s 516ms/step - loss: 0.0520 - dice_coef: 0.9846 - val_loss: 0.0718 - val_dice_coef: 0.9835
# Epoch 17/30
# 117/117 [==============================] - 60s 515ms/step - loss: 0.0658 - dice_coef: 0.9827 - val_loss: 0.0789 - val_dice_coef: 0.9795
# Epoch 18/30
# 117/117 [==============================] - 60s 515ms/step - loss: 0.0602 - dice_coef: 0.9829 - val_loss: 0.0712 - val_dice_coef: 0.9849
# Epoch 19/30
# 117/117 [==============================] - 60s 515ms/step - loss: 0.0518 - dice_coef: 0.9850 - val_loss: 0.0896 - val_dice_coef: 0.9844
# Epoch 20/30
# 117/117 [==============================] - 58s 497ms/step - loss: 0.0468 - dice_coef: 0.9864 - val_loss: 0.0758 - val_dice_coef: 0.9854
# Epoch 21/30
# 117/117 [==============================] - 59s 501ms/step - loss: 0.0447 - dice_coef: 0.9871 - val_loss: 0.0724 - val_dice_coef: 0.9858
# Epoch 22/30
# 117/117 [==============================] - 59s 503ms/step - loss: 0.0428 - dice_coef: 0.9876 - val_loss: 0.0748 - val_dice_coef: 0.9860
# Epoch 23/30
# 117/117 [==============================] - 58s 500ms/step - loss: 0.0417 - dice_coef: 0.9880 - val_loss: 0.0812 - val_dice_coef: 0.9857

# %%
model_new.save_weights(MODEL_DIR)

# %% [markdown]
# ## Get overall test dice and ONL Dice

# %%
test_dataset_batch = test_dataset.batch(BATCH_SIZE)
dice_coefs_test = []
dice_coefs_test_onl = []
for test in test_dataset_batch:
    pred = model_new.predict(test[0])
    dice_coef_ = dice_coef(test[1], pred)
    dice_coefs_test.append(dice_coef_)

    dice_coef_onl = dice_coef(test[1][:, :, :, 2], pred[:, :, :, 2])
    dice_coefs_test_onl.append(dice_coef_onl)


print(np.mean(dice_coefs_test))

print(np.mean(dice_coefs_test_onl))
# Out:
# 0.9849318
# 0.67442936

# %% [markdown]
# ## Validation dice

# %%
dice_coefs_test = []
dice_coefs_test_onl = []
for test in val_dataset:
    pred = model_new.predict(test[0])
    dice_coef_ = dice_coef(test[1], pred)
    dice_coefs_test.append(dice_coef_)

    dice_coef_onl = dice_coef(test[1][:, :, :, 2], pred[:, :, :, 2])
    dice_coefs_test_onl.append(dice_coef_onl)


print(np.mean(dice_coefs_test))

print(np.mean(dice_coefs_test_onl))
# Out:
# 0.98488396
# 0.54485947

# %% [markdown]
# ## Plot results of test set

# %%
test = test_dataset.unbatch().shuffle(SHUFFLE_BUFFER_SIZE).take(90)

for idx, i in enumerate(test):
    pred = model_new.predict(np.expand_dims(i[0].numpy(), axis=0))
    pred = np.argmax(pred, axis=-1)
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
    ax1.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    ax2.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    ax3.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)

    ax1.imshow(pred[0])
    ax2.imshow(np.argmax(i[1], axis=-1))
    ax3.imshow(i[0])
    ax1.set_xlabel("(a)")
    ax2.set_xlabel("(b)")
    ax3.set_xlabel("(c)")
    ax1.set_frame_on(False)
    ax2.set_frame_on(False)
    ax3.set_frame_on(False)
    plt.savefig(FIG_DIR / f"test_set_{idx}.png", dpi=500)
# Out:
# /home/ec2-user/anaconda3/envs/amazonei_tensorflow2_p36/lib/python3.6/site-packages/ipykernel/__main__.py:7: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %% [markdown]
# ## Plot results of valid set

# %%
_, val_dataset_viz, _ = datasets_from_maps(train_x_y_map, val_x_y_map, test_x_y_map, batch_size=BATCH_SIZE)
test = val_dataset_viz.unbatch().shuffle(SHUFFLE_BUFFER_SIZE).take(100)

for idx, i in enumerate(test):
    pred = model_new.predict(np.expand_dims(i[0], axis=0))
    pred = np.argmax(pred, axis=-1)
    fig, (ax1, ax2, ax3) = plt.subplots(1, 3)
    ax1.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    ax2.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)
    ax3.tick_params(left=False, bottom=False, labelleft=False, labelbottom=False)

    ax1.imshow(pred[0])
    ax2.imshow(np.argmax(i[1], axis=-1))
    ax3.imshow(i[0])
    plt.savefig(FIG_DIR / f"valid_set_{idx}.png", dpi=300)
